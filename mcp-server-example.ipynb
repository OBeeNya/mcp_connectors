# %%
from mcp.server.fastmcp import FastMCP

# %%
mcp = FastMCP("AVA")

# %%
@mcp.tool()
def get_api_spec(marketplace: str, version: str = "latest") -> dict:
    """Fetch OpenAPI/WSDL spec for a marketplace. Returns endpoints, schemas, auth."""
    # Loads from local cache or fetches from marketplace developer portal

@mcp.tool()
def list_endpoints(marketplace: str, category: str) -> list[dict]:
    """List endpoints for a domain: orders, products, inventory, fulfillment."""
    # category: "orders" | "catalog" | "inventory" | "fulfillment" | "reports"

@mcp.tool()
def get_auth_config(marketplace: str) -> dict:
    """Return auth scheme: OAuth2 flows, API key headers, SP-API signing, etc."""

@mcp.tool()
def get_rate_limits(marketplace: str, endpoint: str) -> dict:
    """Return rate limit quotas, burst limits, and throttling strategy per endpoint."""

@mcp.tool()
def get_error_codes(marketplace: str) -> list[dict]:
    """Return all documented error codes with descriptions and retry guidance."""
